# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
dataset.drop(columns=['User ID','Gender'],inplace=True)

# %%
sns.scatterplot(x='Age',y='EstimatedSalary',data=dataset,hue='Purchased')
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset['Purchased']

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit(x)
# Out:
# StandardScaler()

# %%
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x.columns
# Out:
# Index(['Age', 'EstimatedSalary'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
dt1 = DecisionTreeClassifier(criterion='entropy')
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt.score(x_test,y_test)*100
# Out:
# 91.25

# %%
dt.score(x_train,y_train)*100
# Out:
# 91.875

# %%
dt1.score(x_test,y_test)*100
# Out:
# 83.75

# %%
dt.predict([[35,20000]])
# Out:
# C:\Users\sujal\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# C:\Users\sujal\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(50,50))
plot_tree(dt)
plt.savefig('demo.jpg')
plt.show()

# %%
for i in range(1,20):
    dt2 = DecisionTreeClassifier(max_depth=i)
    dt2.fit(x_train,y_train)
    print(dt2.score(x_train,y_train),dt2.score(x_test,y_test),i)
# Out:
# 0.821875 0.9 1
# 0.91875 0.9125 2
# 0.91875 0.9125 3
# 0.93125 0.9125 4
# 0.934375 0.9 5
# 0.95 0.8625 6
# 0.96875 0.85 7
# 0.971875 0.85 8
# 0.98125 0.85 9
# 0.984375 0.85 10
# 0.990625 0.8375 11
# 0.990625 0.8375 12
# 0.996875 0.8375 13
# 0.996875 0.8375 14
# 0.996875 0.8375 15
# 0.996875 0.8375 16
# 0.996875 0.8375 17
# 0.996875 0.8375 18
# 0.996875 0.8375 19
