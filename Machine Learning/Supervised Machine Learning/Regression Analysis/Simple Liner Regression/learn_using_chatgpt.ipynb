# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
dataset = pd.read_csv("large_linear_regression_dataset.csv")

# %%
dataset.head()
# Out:
#    CGPA  Internships  Experience_Years  Package_LPA
# 0  6.80            3               1.5         9.56
# 1  9.56            2               1.2        14.27
# 2  8.51            4               1.4        13.64
# 3  7.87            0               0.7        10.11
# 4  5.75            4               2.7        11.70

# %%
x = dataset[['CGPA', 'Internships', 'Experience_Years']]

# %%
y =  dataset["Package_LPA"]

# %%
sns.distplot(dataset["Package_LPA"])
plt.xlabel("CGPA")
plt.ylabel("Package_LPA")
plt.show()
# Out:
# C:\Users\sujal\AppData\Local\Temp\ipykernel_18184\1109088754.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Package_LPA"])

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.8723888098587247

# %%
# plt.scatter(x, y, color='blue')
# plt.plot(x, model.predict(x), color='red')
# plt.xlabel("CGPA")
# plt.ylabel("Package")
# plt.show()

# %%
model.predict([[6.80,3,1.5]])
# Out:
# C:\Users\sujal\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.46789098])
