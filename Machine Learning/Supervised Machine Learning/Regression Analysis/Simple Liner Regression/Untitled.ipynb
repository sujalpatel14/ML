# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("large_linear_regression_dataset.csv")

# %%
dataset.head()
# Out:
#    CGPA  Internships  Experience_Years  Package_LPA
# 0  6.80            3               1.5         9.56
# 1  9.56            2               1.2        14.27
# 2  8.51            4               1.4        13.64
# 3  7.87            0               0.7        10.11
# 4  5.75            4               2.7        11.70

# %%
dataset.isnull().sum()
# Out:
# CGPA                0
# Internships         0
# Experience_Years    0
# Package_LPA         0
# dtype: int64

# %%
sns.scatterplot(x="CGPA",y="Package_LPA",data=dataset)
plt.show()

# %%
x = dataset[["CGPA"]]
y = dataset["Package_LPA"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=50,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[6.80]])
# Out:
# C:\Users\sujal\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.72429197])

# %%
lr.score(x_test,y_test)*100
# Out:
# 59.60659152761373

# %%
lr.coef_
# Out:
# array([1.17190382])

# %%
lr.intercept_
# Out:
# np.float64(2.7553460159746486)

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="CGPA",y="Package_LPA",data=dataset)
plt.plot(dataset["CGPA"],y_prd,color="red")
plt.legend(['org',"predict line"])
plt.show()
