# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "size" : [2104,1416,1534,852],
    "room" : [5,3,3,2],
    "floor" : [1,2,2,1],
    "house age" : [45,40,30,36],
    "price" : [460,232,315,178]
}

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#    size  room  floor  house age  price
# 0  2104     5      1         45    460
# 1  1416     3      2         40    232
# 2  1534     3      2         30    315
# 3   852     2      1         36    178

# %%
x = np.array(dataset.iloc[:,:-1])

# %%
y = np.array(dataset["price"])

# %%
x = np.c_[np.ones(len(x)),x]

# %%
all_theta = np.linalg.pinv(x)@y

# %%
all_theta
# Out:
# array([188.40031942,   0.3866255 , -56.13824955, -92.9672536 ,
#         -3.73781915])

# %%
pr = 188.40031942 + (0.3866255*1416)  -(56.13824955*3) -(92.9672536*2) -(3.73781915*40)

# %%
pr
# Out:
# 232.00000557000004
